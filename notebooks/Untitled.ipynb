# %%
import scanpy as sc
sc.__version__
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_26428\2798337852.py:2: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   sc.__version__
# '1.11.5'

# %%
import os, glob

glob.glob("../data/*.gz")
# Out:
# ['../data\\GSE131907_Lung_Cancer_raw_UMI_matrix .txt.gz']

# %%
import pandas as pd
import scanpy as sc
from scipy import sparse

path = r"C:\Users\PC\OneDrive\Documents\Bioinformatics\tumor-immune-evasion-atlas\data\GSE131907_Lung_Cancer_raw_UMI_matrix.txt.gz"


df = pd.read_csv(path, sep="\t", index_col=0)

print("Loaded! Shape of table:")
print(df.shape)

df.iloc[:5, :5]

# %%
import scanpy as sc

path = r"C:\Users\PC\OneDrive\Documents\Bioinformatics\tumor-immune-evasion-atlas\data\GSE131907_Lung_Cancer_raw_UMI_matrix.txt.gz"

adata = sc.read_text(path, delimiter="\t")

adata
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 5
#       1 import scanpy as sc
#       3 path = r"C:\Users\PC\OneDrive\Documents\Bioinformatics\tumor-immune-evasion-atlas\data\GSE131907_Lung_Cancer_raw_UMI_matrix.txt.gz"
# ----> 5 adata = sc.read_text(path, delimiter="\t")
#       7 adata
#
# File ~\miniconda3\envs\tumorimmuno\lib\site-packages\anndata\_io\read.py:351, in read_text(filename, delimiter, first_column_names, dtype)
#     349 if filename.suffix == ".gz":
#     350     with gzip.open(str(filename), mode="rt") as f:
# --> 351         return _read_text(f, delimiter, first_column_names, dtype)
#     352 elif filename.suffix == ".bz2":
#     353     with bz2.open(str(filename), mode="rt") as f:
#
# File ~\miniconda3\envs\tumorimmuno\lib\site-packages\anndata\_io\read.py:455, in _read_text(f, delimiter, first_column_names, dtype)
#     450     msg = (
# ...
